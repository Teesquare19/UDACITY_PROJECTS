# %% [markdown]
# ## Analysis and Insights
#
# Data Focus: WeRateDog; By Titilope Onabajo

# %% [markdown]
# ## Wrangling, Analyzing and Visualizing Data
#
#  -In this section, in a bid to analyze and visualize the wrangled data, the data used is the`twitter_archive_master` data. This  was formed from the merging of the 3 raw data made available (`df_archive`, `df_image`, `df_tweet`) after cleaning, wrangling and dropping all unused columns. To further drive down,five insights was drawn, analyzed and visualized.

# %% [markdown]
# ### Insights One

# %% [markdown]
# This was carried out to show if there is a relationship between the number of favorite counts and the number of retweets over the time under review. The graph shows that the favorite and retweet count increased in tandem with each other over time

# %% [markdown]
# ![output5.png](attachment:output5.png)

# %% [markdown]
# ### Insights Two

# %% [markdown]
# This insights shows that over time (i.e between 2016-01 and 2017-07) tweet trend declined. This could mean that twutter users
# might be gradually becoming uniterested in tweeting about dog ratings and want a newer challenge.

# %% [markdown]
# ![output4.png](attachment:output4.png)

# %% [markdown]
# ### Insights Three

# %% [markdown]
# This insights was targeted to show the most rated dog types amidst the  entire list of dog types gathered in the dataset.
#
# This shows the top dogs from the ratings by twitter users in the WeRateDog tweets.

# %% [markdown]
# ![baroutput.png](attachment:baroutput.png)

# %% [markdown]
# ### Insights Four

# %% [markdown]
# This analysis shows us that iphone represents 98.1% of twitter users that interact with the weratedog tweets,  with less than 2% being accessed from twitter web and twitter deck.

# %% [markdown]
# ![output.png](attachment:output.png)

# %% [markdown]
# ### Insights Five

# %% [markdown]
# The	blue	dot	 which is an outlier on	the	very	right represents the dog type; golden	retriever with an average rating of 27.0 . It seems to reflect that the	golden	retriever is highly rated.

# %% [markdown]
# ![output2.png](attachment:output2.png)
